# %%
from dotenv import load_dotenv
from sqlalchemy import create_engine
import os
import json
import pandas as pd

load_dotenv()
DATABASE_URL = os.getenv("DATABASE_URL")
engine = create_engine(DATABASE_URL)

# %%
with open("data/raw/resultados_classificacao.json", "r", encoding="utf-8") as f:
    resultados = json.load(f)

df_resultados = pd.DataFrame(resultados)
print(df_resultados.shape)
df_resultados.head(3)
# Out:
# (9301, 2)
#        id        tema
# 0  106701  Tecnologia
# 1  155019  Tributário
# 2  264726   Segurança

# %%
df_resultados.to_sql("classificacoes", engine, if_exists="replace", index=False)
print("Carga concluída!")
# Out:
# Carga concluída!
